# %%
# %matplotlib inline
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
test1,test2 = pd.read_csv("test/outwc_variando_n_v1000.csv"), pd.read_csv("test/outwc_variando_n_v10000.csv")
test13 = pd.read_csv("test/outwc_variando_n_v7500.csv")
test3 = pd.read_csv("test/outwc_variando_n_v100.csv")
test4 = pd.read_csv("test/outwc_variando_n_v500.csv")

test25=pd.read_csv("test/outwc_variando_n_v2500.csv")
test75=pd.read_csv("test/outwc_variando_n_v7500.csv")
test20k = pd.read_csv("test/outwc_variando_n_v20000.csv")
test50k=pd.read_csv("test/outwc_variando_n_v50000.csv")
test12 = pd.read_csv("test/outwc_variando_n_v5000.csv")
test5 = pd.read_csv("test/outwc_variando_v_n15.csv")
test20 = pd.read_csv("test/outwc_variando_v_n20.csv")
test7 = pd.read_csv("test/outwc_variando_v_n25.csv")
test24 = pd.read_csv("test/outwc_variando_v_n24.csv")
test9 = pd.read_csv("test/outwc_variando_v_n30.csv")
test9p = pd.read_csv("test/outwc_variando_v_n30.csv")
test10 = pd.read_csv("test/outwc_variando_v_n40.csv")
testpd = pd.read_csv("test/outwc_variando_ambos.csv")
test200 = pd.read_csv("test/outwc_variando_n_v200.csv")
test400 = pd.read_csv("test/outwc_variando_n_v400.csv")
test600 = pd.read_csv("test/outwc_variando_n_v600.csv")
test800 = pd.read_csv("test/outwc_variando_n_v800.csv")
test26 = pd.read_csv("test/outwc_variando_v_n26.csv")
testpd100 = pd.read_csv("test/outwc_n1_v100.csv")
testpd200 = pd.read_csv("test/outwc_n1_v200.csv")
testpd2 = pd.read_csv("test/outwc_variando_ambos_e1.csv")
testambos2 = pd.read_csv("test/outwc_variando_ambos2.csv")
tambos = pd.DataFrame(testambos2)
testpd = pd.read_csv("test/outwc_variando_ambos.csv")
test35=pd.read_csv("test/outwc_variando_v_n35_e1.csv")
test200 = pd.read_csv("test/outwc_variando_n_v200.csv")
test10p = pd.read_csv("test/outwc_variando_n_v10.csv")
t10p = pd.DataFrame(test10p)
test140 = pd.read_csv("test/outwc_variando_n_v140.csv")
t140 = pd.DataFrame(test140)
test20 = pd.read_csv("test/outwc_variando_n_v20.csv")
t20 = pd.DataFrame(test20)
test40p = pd.read_csv("test/outwc_variando_n_v40.csv")
t40 = pd.DataFrame(test40p)
test80 = pd.read_csv("test/outwc_variando_n_v80.csv")
t80 = pd.DataFrame(test80)
test100 = pd.read_csv("test/outwc_variando_n_v100.csv")
t100 = pd.DataFrame(test100)
test280 = pd.read_csv("test/outwc_variando_n_v280.csv")
t280 = pd.DataFrame(test280)
test50 = pd.read_csv("test/outwc_variando_n_vncuad.csv")
test60 = pd.read_csv("test/outwc_variando_n_v10000.csv")

test500 = pd.read_csv("test/outwc_variando_n_v500.csv")
t500p = pd.DataFrame(test500)

# %%
t1000 , t10000= pd.DataFrame(test1), pd.DataFrame(test2)
t100 = pd.DataFrame(test3)
t500 = pd.DataFrame(test4)
t15 = pd.DataFrame(test5)
t20 = pd.DataFrame(test20)
t25 = pd.DataFrame(test7)
t30 = pd.DataFrame(test9)
t50000 = pd.DataFrame(test50k)
t20000 = pd.DataFrame(test20k)
tpd2 = pd.DataFrame(testpd2)
t7500 = pd.DataFrame(test75)
t40 = pd.DataFrame(test10)
t2500 = pd.DataFrame(test25)
t26 = pd.DataFrame(test26)
tva = pd.DataFrame(test8)
t5000 = pd.DataFrame(test12)
t24 = pd.DataFrame(test24)
t30p = pd.DataFrame(test9p)
t35 = pd.DataFrame(test35)
tpd100 = pd.DataFrame(testpd100)
tpd200 = pd.DataFrame(testpd200)
tpd = pd.DataFrame(testpd)
t200= pd.DataFrame(test120)
t60 = pd.DataFrame(test60)
t50 = pd.DataFrame(test50)

# %%
d = []
for i in range(6,26):
    d.append({'TAM': i, 'bf': (2**i)*i})
bf = pd.DataFrame(d)
#plt.plot(t100["TAM"],t100["T-FUERZA-BRUTA"])
t100 = t100["T-FUERZA-BRUTA"]/bf["bf"]
t200 = t100["T-FUERZA-BRUTA"]/bf["bf"]
t500 = t100["T-FUERZA-BRUTA"]/bf["bf"]
t25000 = t100["T-FUERZA-BRUTA"]/bf["bf"]
t100 = t100["T-FUERZA-BRUTA"]/bf["bf"]
plt.plot(t100["TAM"],t100)

# %%
t120
# Out:
#     TAM  T-FUERZA-BRUTA  T-BACKTRACKING  T-TOP-DOWN  T-BOTTOM-UP  SOLUCION  \
# 0     0               0            0.00        0.00         0.00        -1
# 1     2               0            0.00        0.00         0.00        -1
# 2     4               0            0.00        0.00         0.00        -1
# 3     6               0            0.00        0.00         0.00        -1
# 4     8               0            0.00        0.00         0.00        -1
# 5    10               0            0.00        0.00         0.00         2
# 6    12               0            0.00        0.00         0.00         2
# 7    14               0            0.00        0.00         0.00         2
# 8    16               0            0.00        0.00         0.00         3
# 9    18               0            0.00        0.00         0.25         2
# 10   20               0            0.00        0.00         0.25         2
# ...

# %%
##### td = tva.pivot("TAM", "V","T-TOP-DOWN")

td = tambos.pivot("TAM","V","T-TOP-DOWN")
bu = tpd2.pivot("TAM","V","T-BOTTOM-UP")
ax = sns.heatmap(td,cmap="YlGnBu")#, annot=True)
#bu = td.pivot("TAM","V","T-TOP-DOWN")
#ax = sns.heatmap(bu,cmap="YlGnBu")
ax.invert_yaxis()
plt.title("Algoritmo Top-Down variando n y v simultaneamente")
plt.savefig("td_var_n_v_heatmap")
plt.show()

# %%
##### td = tva.pivot("TAM", "V","T-TOP-DOWN")
bu = tambos.pivot("TAM","V","T-BOTTOM-UP")
ax = sns.heatmap(bu,vmin=0,vmax=80,cmap="YlGnBu")#, annot=True)
#bu = td.pivot("TAM","V","T-TOP-DOWN")
#ax = sns.heatmap(bu,cmap="YlGnBu")
ax.invert_yaxis()
plt.title("Algoritmo Bottom-UP variando n y v simultaneamente")
plt.savefig("bu_var_n_v_heatmap")
plt.show()

# %%
#plt.yscale('log')
  #plt.xscale('log')

plt.plot(t1000["TAM"],t1000["T-BACKTRACKING"])
plt.plot(t1000["TAM"],t1000["T-BOTTOM-UP"])
plt.title("Valor objetivo = 1000")
plt.ylabel("Tiempo(ms)")
plt.xlabel("TAM C")
plt.legend(["Backtracking","Bottom Up"])

# %%
#btgraf = bt.plot("TAM", "BACKTRACKING",title="")
#bfgraf = bf.plot("TAM","FUERZA-BRUTA",title="")
#ax = btgraf
#bf.plot(ax=ax)
d = []
for i in range(6,26):
    d.append({'TAM': i, 'pd': (i * 1000)})
dp= pd.DataFrame(d)
#plt.plot(t100["TAM"],t100["T-FUERZA-BRUTA"])
t1000p = t1000["T-TOP-DOWN"]/dp["pd"]

d = []
for i in range(6,26):
    d.append({'TAM': i, 'pd': (i * 2500)})
dp= pd.DataFrame(d)
t2500p = t2500["T-TOP-DOWN"]/dp["pd"]

d = []
for i in range(6,26):
    d.append({'TAM': i, 'pd': (i * 5000)})
dp= pd.DataFrame(d)
t5000p = t5000["T-TOP-DOWN"]/dp["pd"]

d = []
for i in range(6,26):
    d.append({'TAM': i, 'pd': (i * 10000)})
dp= pd.DataFrame(d)
t10000p = t10000["T-TOP-DOWN"]/dp["pd"]

d = []
for i in range(6,26):
    d.append({'TAM': i, 'pd': (i * 20000)})
dp= pd.DataFrame(d)
t20000p = t20000["T-TOP-DOWN"]/dp["pd"]


plt.plot(t1000["TAM"],t1000p)
plt.plot(t2500["TAM"],t2500p)
plt.plot(t5000["TAM"],t5000p)
plt.plot(t10000["TAM"],t10000p)
plt.plot(t20000["TAM"],t20000p)
#plt.plot(t2500["TAM"],t2500["T-FUERZA-BRUTA"])
plt.axis([0,38,0,0.00099])
plt.xlabel("Valor objetivo")
plt.title("Top-Down")
plt.ylabel("Top-Down / n x V")
#plt.plot(n,bu,label='Buttom Up')
plt.legend(["v=1000","v=2500","v=5000","v=10000","v=20000"])

#plt.savefig('td_nxv.png')

# %%
#plt.yscale("log")
d = []
for i in range(6,26):
    d.append({'TAM': i, 'pd': (i * 1000)})
dp= pd.DataFrame(d)
t1000p = t1000["T-BOTTOM-UP"]/dp["pd"]

d = []
for i in range(6,26):
    d.append({'TAM': i, 'pd': (i * 2500)})
dp= pd.DataFrame(d)
t2500p = t2500["T-BOTTOM-UP"]/dp["pd"]


d = []
for i in range(6,26):
    d.append({'TAM': i, 'pd': (i * 5000)})
dp= pd.DataFrame(d)
t5000p = t5000["T-BOTTOM-UP"]/dp["pd"]


d = []
for i in range(6,26):
    d.append({'TAM': i, 'pd': (i * 10000)})
dp= pd.DataFrame(d)
t10000p = t10000["T-BOTTOM-UP"]/dp["pd"]

d = []
for i in range(6,26):
    d.append({'TAM': i, 'pd': (i * 20000)})
dp= pd.DataFrame(d)
t120000p = t20000["T-BOTTOM-UP"]/dp["pd"]

plt.plot(t1000["TAM"],t1000p)
plt.plot(t2500["TAM"],t2500p)
plt.plot(t5000["TAM"],t5000p)
plt.plot(t10000["TAM"],t10000p)
plt.plot(t20000["TAM"],t20000p)
#plt.plot(t2500["TAM"],t2500["T-FUERZA-BRUTA"])
plt.axis([0,38,0,0.0008])
plt.xlabel("Valor objetivo")
plt.title("Bottom-Up")
plt.ylabel("Bottom-Up / n x V")
#plt.plot(n,bu,label='Buttom Up')
plt.legend(["v=1000","v=2500","v=5000","v=10000"])
plt.xlabel("TAM C")
#plt.plot(n,bu,label='Buttom Up')
plt.legend(["v=1000","v=2500","v=5000","v=10000","v=20000"])


#plt.savefig('bu_nxv_n')

# %%
#plt.yscale("log")
d = []
for i in range(6,26):
    d.append({'TAM': i, 'pd': (i * 1000)})
dp= pd.DataFrame(d)
t1000p = t1000["T-TOP-DOWN"]/dp["pd"]

d = []
for i in range(6,26):
    d.append({'TAM': i, 'pd': (i * 2500)})
dp= pd.DataFrame(d)
t2500p = t2500["T-TOP-DOWN"]/dp["pd"]


d = []
for i in range(6,26):
    d.append({'TAM': i, 'pd': (i * 5000)})
dp= pd.DataFrame(d)
t5000p = t5000["T-TOP-DOWN"]/dp["pd"]


d = []
for i in range(6,26):
    d.append({'TAM': i, 'pd': (i * 10000)})
dp= pd.DataFrame(d)
t10000p = t10000["T-TOP-DOWN"]/dp["pd"]

d = []
for i in range(6,26):
    d.append({'TAM': i, 'pd': (i * 20000)})
dp= pd.DataFrame(d)
t120000p = t20000["T-TOP-DOWN"]/dp["pd"]

plt.plot(t1000["TAM"],t1000p)
plt.plot(t2500["TAM"],t2500p)
plt.plot(t5000["TAM"],t5000p)
plt.plot(t10000["TAM"],t10000p)
plt.plot(t20000["TAM"],t20000p)
#plt.plot(t2500["TAM"],t2500["T-FUERZA-BRUTA"])
plt.axis([0,38,0,0.0008])
plt.xlabel("TAM C")
plt.title("TOP-DOWN")
plt.ylabel("TOP-DOWN / n x V")
#plt.plot(n,bu,label='Buttom Up')
plt.legend(["v=1000","v=2500","v=5000","v=10000"])
plt.xlabel("TAM C")
#plt.plot(n,bu,label='Buttom Up')
plt.legend(["v=1000","v=2500","v=5000","v=10000","v=20000"])
